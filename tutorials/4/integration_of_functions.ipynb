# %%
import sys

sys.path.append("/home/milan/Desktop/NURa")

# %%
from algorithms.integration import integration_methods as int
import numpy as np

# %%
#1a

# %%
#1b

# %%
#1c

print(int.romberg(lambda x: x**3, a=0, b=2, m=4, N=1))
print(int.romberg(np.sin, a=0, b=2*np.pi, m=6, N=8))
# Out:
# (4.0, 0.0)
# (0.0057232807503402984, 5.599672207898948e-06)
