# %%
import sys

sys.path.append("/home/milan/Desktop/NURa")

# %%
from algorithms.integration import integration_methods as int
import numpy as np

# %%
#1a

# %%
#1b

# %%
#1c

print(int.romberg(lambda x: x**3, a=0, b=2, order=4))
print(int.romberg(np.sin, a=0, b=1.5*np.pi, order=3))
print(int.romberg(np.sin, a=0, b=1.5*np.pi, order=5))
print(int.romberg(np.sin, a=0, b=1.5*np.pi, order=7))
print(int.romberg(np.sin, a=0, b=1.5*np.pi, order=9))
# Out:
# (4.0, 0.0)
# (0.9845519201614213, 0.028218211595019693)
# (0.9999997004958525, 5.331660515306424e-07)
# (0.9999999999999769, 4.0190073491430667e-14)
# (1.0, 0.0)
