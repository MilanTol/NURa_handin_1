# %%
import sys

sys.path.append("/home/milan/Desktop/NURa")

# %%
import numpy as np

# %%
from algorithms.linear_systems.matrix import Matrix
from algorithms.linear_systems.Gauss import Gauss

# %%
mat = np.array([
    [3, 8, 1, -12, -4],
    [1, 0, 0, -1, -0],
    [4, 4, 3, -40, -3],
    [0, 2, 1, -3, -2],
    [0, 1, 0, -12, -0]
])
mat = Matrix(mat)

b= np.array([2, 0, 1, 0, 0])
b = Matrix(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       1 mat = np.array([
#       2     [3, 8, 1, -12, -4],
#       3     [1, 0, 0, -1, -0],
#    (...)
#       6     [0, 1, 0, -12, -0]
#       7 ])
# ----> 8 mat = Matrix(mat)
#      10 b= np.array([2, 0, 1, 0, 0])
#      11 b = Matrix(b)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
gauss = Gauss(mat, b)
gauss.cast()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 gauss = Gauss(mat, b)
# ----> 2 gauss.cast()
#
# File ~/Desktop/NURa/algorithms/linear_systems/Gauss.py:25, in Gauss.cast(self)
#      23 for column in range(N):
#      24     for row in range(N)[column:]: #loop over rows with row >= column
# ---> 25         self.set_pivot(row, column)
#      27     self.empty_lower_rows(column)
#      28 return b
#
# File ~/Desktop/NURa/algorithms/linear_systems/Gauss.py:34, in Gauss.set_pivot(self, row, column)
#      32 if self.mat[row, column] != 0:
#      33     if row != column:
# ---> 34         self.mat.swap_rows(column, row) #swap row with index=column with pivot row
#      35         self.b.swap_rows(column, row)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'swap_rows'

# %%
x = gauss.solve()

print(x)
# Out:
# /home/milan/Desktop/NURa/algorithms/linear_systems/Gauss.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   self.b[i] = 1/self.mat[i, i] * (self.b[i] - np.sum(self.mat[i, i:]*self.b[i:]))
# /home/milan/Desktop/NURa/algorithms/linear_systems/Gauss.py:47: RuntimeWarning: invalid value encountered in scalar multiply
#   self.b[i] = 1/self.mat[i, i] * (self.b[i] - np.sum(self.mat[i, i:]*self.b[i:]))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x = gauss.solve()
#       3 print(x)
#
# File ~/Desktop/NURa/algorithms/linear_systems/Gauss.py:47, in Gauss.solve(self)
#      45 def solve(self):
#      46     for i in range(self.N):
# ---> 47         self.b[i] = 1/self.mat[i, i] * (self.b[i] - np.sum(self.mat[i, i:]*self.b[i:]))
#      48     return self.b
#
# ValueError: cannot convert float NaN to integer
